# %% [markdown]
# ## How to Make a Box Plot in ggplot2
#
# This tutorial creates a unique dataset using the ages of 20 study subjects from two groups (A,B) to construct a box plot.

# %% [markdown]
# ### Create the data set

# %% [markdown]
# Create a vector containing the group assignments (A or B) for 20 participants.

# %%
v1 <- c(rep("A",10),rep("B",10))
v1
# Out:
#  [1] "A" "A" "A" "A" "A" "A" "A" "A" "A" "A" "B" "B" "B" "B" "B" "B" "B" "B" "B"
# [20] "B"

# %% [markdown]
# Create a second vector containing random ages for 20 people between 15 and 65 years old.

# %%
v2 <- c(runif(20,min=15, max = 65))
v2
# Out:
#  [1] 50.57872 47.65802 27.93188 48.41602 29.80159 21.83437 32.81319 39.27308
#  [9] 42.25784 41.04151 38.89697 16.00959 64.57534 61.03727 21.47676 29.17113
# [17] 21.00930 22.83195 46.52538 30.53734

# %% [markdown]
# The numbers generated above have decimals. We want ages as integers so round all the values of v2.

# %%
v2 <- round(v2)
v2
# Out:
#  [1] 51 48 28 48 30 22 33 39 42 41 39 16 65 61 21 29 21 23 47 31

# %% [markdown]
# We have a vector of group assignments and a vector of ages. Now combine them to make a data frame.

# %%
df <- data.frame(v1,v2)
df
# Out:
#    v1 v2
# 1  A  51
# 2  A  48
# 3  A  28
# 4  A  48
# 5  A  30
# 6  A  22
# 7  A  33
# 8  A  39
# 9  A  42
# 10 A  41
# 11 B  39
# 12 B  16
# 13 B  65
# 14 B  61
# 15 B  21
# 16 B  29
# 17 B  21
# 18 B  23
# 19 B  47
# 20 B  31

# %% [markdown]
# Now name the columns for clarity and ease when making plots.

# %%
colnames(df) <- c("Group","Age")
df
# Out:
#    Group Age
# 1  A     51
# 2  A     48
# 3  A     28
# 4  A     48
# 5  A     30
# 6  A     22
# 7  A     33
# 8  A     39
# 9  A     42
# 10 A     41
# 11 B     39
# 12 B     16
# 13 B     65
# 14 B     61
# 15 B     21
# 16 B     29
# 17 B     21
# 18 B     23
# 19 B     47
# 20 B     31

# %% [markdown]
# ### Make a box plot

# %% [markdown]
# Load the package "ggplot2" to make the plot.

# %%
library(ggplot2)

# %% [markdown]
# Start with a basic box plot where Group is on the x axis and Age is on the Y axis. Assign this plot to an object we can call later if we want to add other features.
# In the basic plot we can also color our boxes based on group.
# The ggplot() function creates the basic structure of the plot and the geom_boxplot() function indicates how we'd like to display the data (as a boxplot).

# %%
Plot <- ggplot(df, aes(x=Group, y = Age, color = Group)) + geom_boxplot()
Plot
# Out:
# plot without title

# %% [markdown]
# Now that we have our basic plot, we can add stat_summary() to display statistical values such as the mean ages for both groups. We want the mean to be displayed by a point on the map in a diamond shape (shape=23) and we want it a bit bigger than default (size = 5).

# %%
Plot + stat_summary(fun=mean, geom="point", shape=23, size=5)
# Out:
# plot without title

# %% [markdown]
# Finally, we are curious where all our participants fall in these box plots so we can overlay points for each individual. We will use geom_jitter() to avoid overlapping points. We can again customize what shape and size the points will be and how much "jitter" to use.
#
# Hint: If you want the dots more spread out try position=position_jitter(0.2)

# %%
Plot + stat_summary(fun=mean, geom="point", shape=23, size=5) + geom_jitter(shape=16, size= 3, position=position_jitter(0.1))
# Out:
# plot without title

# %% [markdown]
# For more tips and features to customize your boxplot see: http://www.sthda.com/english/wiki/ggplot2-box-plot-quick-start-guide-r-software-and-data-visualization
